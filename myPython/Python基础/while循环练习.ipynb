# %%
benjin = input('请输入您的: benjin ')
benjin = int(benjin)
year = 0
over = benjin * 2
while benjin >= over:
    benjin >= benjin * (1 + 0.055)
    year += 1 # 这个等于year = year + 1
    print("第 {0} 年，拿了{1} 块钱".format(year,benjin))
else:
    print('终于那翻倍了，等的太心累了')
    print('10年前10万块钱可以买套房，现在儿子结婚，10万块钱，就买个厨房')
# Out:
# 请输入您的: benjin 313213
# 终于那翻倍了，等的太心累了
# 10年前10万块钱可以买套房，现在儿子结婚，10万块钱，就买个厨房

# %%
benjin = input('请输入您的本金:')
a = input('请输入对应利率')
benjin = int(benjin)
a = float(a)
year = 0
over = benjin * 2
while benjin <= over:
    benjin = benjin * (1 + a)
    year += 1 # 这个等于year = year + 1
    print("第 {0} 年，拿了{1} 块钱".format(year,benjin))
else:
    print('终于那翻倍了，等的太心累了')
    print('10年前10万块钱可以买套房，现在儿子结婚，10万块钱，就买个厨房')
# Out:
# 请输入您的本金:1213123132213
# 请输入对应利率0.022
# 第 1 年，拿了1239811841121.686 块钱
# 第 2 年，拿了1267087701626.363 块钱
# 第 3 年，拿了1294963631062.143 块钱
# 第 4 年，拿了1323452830945.5103 块钱
# 第 5 年，拿了1352568793226.3115 块钱
# 第 6 年，拿了1382325306677.2903 块钱
# 第 7 年，拿了1412736463424.1907 块钱
# 第 8 年，拿了1443816665619.523 块钱
# 第 9 年，拿了1475580632263.1526 块钱
# 第 10 年，拿了1508043406172.942 块钱
# 第 11 年，拿了1541220361108.7466 块钱
# 第 12 年，拿了1575127209053.139 块钱
# 第 13 年，拿了1609780007652.308 块钱
# 第 14 年，拿了1645195167820.659 块钱
# 第 15 年，拿了1681389461512.7134 块钱
# 第 16 年，拿了1718380029665.9932 块钱
# 第 17 年，拿了1756184390318.645 块钱
# 第 18 年，拿了1794820446905.6553 块钱
# 第 19 年，拿了1834306496737.5798 块钱
# 第 20 年，拿了1874661239665.8066 块钱
# 第 21 年，拿了1915903786938.4543 块钱
# 第 22 年，拿了1958053670251.1003 块钱
# 第 23 年，拿了2001130850996.6245 块钱
# 第 24 年，拿了2045155729718.5503 块钱
# 第 25 年，拿了2090149155772.3584 块钱
# 第 26 年，拿了2136132437199.3503 块钱
# 第 27 年，拿了2183127350817.736 块钱
# 第 28 年，拿了2231156152535.7266 块钱
# 第 29 年，拿了2280241587891.5127 块钱
# 第 30 年，拿了2330406902825.126 块钱
# 第 31 年，拿了2381675854687.279 块钱
# 第 32 年，拿了2434072723490.399 块钱
# 终于那翻倍了，等的太心累了
# 10年前10万块钱可以买套房，现在儿子结婚，10万块钱，就买个厨房
